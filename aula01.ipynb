# %%
import pandas as pd
df = pd.read_excel('brasil_estados.xlsx')

# %%
df
# Out:
#                  Estado Sigla        Região  População  Densidade Demográfica  \
# 0                  Acre    AC         Norte     830026                   5.06
# 1               Alagoas    AL      Nordeste    3127511                 112.38
# 2                 Amapá    AP         Norte     733508                   5.15
# 3              Amazonas    AM         Norte    3941175                   2.53
# 4                 Bahia    BA      Nordeste   14136417                  25.03
# 5                 Ceará    CE      Nordeste    8791688                  59.05
# 6      Distrito Federal    DF  Centro Oeste    2817068                 489.01
# 7        Espírito Santo    ES       Sudeste    3883486                  83.20
# 8                 Goiás    GO  Centro Oeste    7055228                  20.74
# 9              Maranhão    MA      Nordeste    6775152                  20.55
# 10          Mato Grosso    MT  Centro Oeste    3658813                   4.05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Estado                 27 non-null     object
#  1   Sigla                  27 non-null     object
#  2   Região                 27 non-null     object
#  3   População              27 non-null     int64
#  4   Densidade Demográfica  27 non-null     float64
#  5   Veículos               27 non-null     int64
#  6   IDEB EF                27 non-null     float64
#  7   IDEB EM                27 non-null     float64
#  8   Rendimento per Capita  27 non-null     int64
#  9   Ocupação               27 non-null     float64
#  10  Rendimento Ocupação    27 non-null     int64
#  11  IDH                    27 non-null     float64
#  12  Área                   27 non-null     int64
#  13  Área Urbana            27 non-null     float64
# ...
